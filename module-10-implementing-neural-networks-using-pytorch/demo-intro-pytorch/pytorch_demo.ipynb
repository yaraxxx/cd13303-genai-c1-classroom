# %% [markdown]
# # Introduction to PyTorch
#
# PyTorch is a key tool for machine learning and deep learning. Think of it as a mechanic's toolbox, providing everything you need to easily build and train complex models. This notebook will give you a solid understanding of PyTorch's core concepts, enabling you to expand your knowledge and explore the depths of machine learning models.
#
# ## Outline
#
# We'll cover the following topics:
# * **PyTorch Tensors**: Multidimensional arrays and the foundational data structure in PyTorch.
# * **Neural Nets in PyTorch**: Handled by the useful `torch.nn` module.
# * **PyTorch Loss Functions**: Define the objective function we wish to minimize during training.
# * **PyTorch Optimizers**: The algorithms we use for minimizing our loss functions.
# * **Datasets and Data Loaders in PyTorch**: Useful tools for working with data at scale easily.
# * **Training loops in PyTorch**: Define the fundamental steps for training a deep learning model.
#
# ## PyTorch Tensors
#
# Drawing a parallel to mathematics, tensors can be likened to vectors and matrices, but with the capability to have more than two dimensions.
#
# Let’s take a look at using pytorch tensors to store images. Suppose we have four grayscale images, each of size 28x28 pixels. We can represent these images as a 4x28x28 tensor in PyTorch. Here, `images` is a 3D tensor where the first dimension corresponds to the number of images, and the subsequent dimensions represent the height and width of each image. In this case we’ll create 4 images of random noise.

# %%
import torch
import matplotlib.pyplot as plt

images = torch.rand(4, 28, 28)
# To access the second image
second_image = images[1]
print(second_image)
# Out:
# tensor([[2.2726e-01, 1.2607e-01, 4.3409e-01, 5.9893e-01, 7.4419e-01, 1.6004e-02,
#          5.2517e-01, 1.3525e-02, 4.3670e-01, 4.1766e-01, 1.2908e-01, 9.8416e-01,
#          5.7982e-01, 4.3794e-01, 7.4958e-01, 4.1883e-01, 2.0861e-02, 4.2204e-01,
#          9.7770e-01, 9.0169e-01, 7.4240e-01, 1.5543e-01, 5.5565e-01, 5.4667e-01,
#          2.6219e-01, 4.5110e-01, 9.4071e-01, 7.3030e-01],
#         [7.3895e-01, 1.1789e-02, 7.5051e-02, 9.7644e-01, 7.0337e-01, 1.6507e-02,
#          9.2930e-01, 9.4447e-01, 6.1266e-01, 3.5718e-01, 7.2645e-01, 3.2392e-01,
#          6.8777e-01, 7.8672e-01, 7.6140e-02, 4.5176e-01, 1.9160e-01, 4.1221e-01,
#          1.0405e-01, 5.8655e-01, 2.3436e-01, 7.0036e-01, 7.0851e-01, 7.0357e-01,
#          1.6862e-01, 8.6156e-01, 7.5258e-01, 3.0527e-01],
#         [6.5908e-01, 7.6271e-01, 5.6499e-01, 1.1103e-01, 4.2068e-01, 7.3367e-01,
#          1.3661e-01, 9.3806e-01, 4.5931e-01, 6.5757e-01, 6.7872e-01, 3.6333e-01,
#          4.3082e-01, 9.6071e-01, 8.1461e-02, 1.0426e-01, 1.3475e-01, 5.1228e-01,
#          3.3384e-01, 8.2724e-01, 5.0893e-01, 8.2808e-01, 7.7523e-03, 7.8625e-01,
#          8.5454e-01, 9.0511e-02, 3.3349e-01, 9.0850e-01],
#         [4.4747e-02, 9.6803e-01, 8.0542e-01, 2.1347e-01, 8.6130e-01, 9.9907e-01,
#          6.8335e-01, 9.7732e-01, 6.4297e-01, 4.2817e-01, 7.2154e-01, 7.5447e-01,
#          7.6334e-01, 8.9823e-01, 3.1595e-02, 9.4782e-01, 7.1960e-01, 5.5488e-01,
#          2.3230e-01, 6.7176e-01, 3.4788e-01, 6.5784e-01, 3.2628e-01, 8.3536e-04,
#          6.1085e-01, 7.5875e-01, 4.2772e-01, 2.9118e-01],
#         [5.7570e-01, 1.2897e-01, 9.3600e-01, 8.7265e-01, 2.5206e-01, 8.7006e-01,
#          6.4443e-01, 2.1636e-01, 9.6287e-01, 6.0961e-01, 8.1268e-01, 8.0414e-01,
#          1.6607e-01, 2.3414e-01, 3.0781e-01, 1.2355e-01, 7.3436e-01, 8.6329e-01,
#          9.1613e-01, 5.3353e-01, 9.3162e-01, 7.1375e-01, 2.9080e-01, 5.9713e-02,
#          9.2292e-01, 3.2782e-02, 4.0626e-01, 3.1259e-01],
#         [6.3120e-01, 8.2909e-01, 3.3798e-02, 9.5546e-01, 1.4703e-02, 1.0777e-01,
#          5.6092e-01, 4.2927e-01, 3.4638e-01, 9.8936e-01, 9.3348e-01, 4.2737e-01,
#          6.6343e-01, 3.0325e-01, 8.8212e-01, 5.7884e-01, 5.5993e-01, 2.3704e-01,
#          6.4459e-01, 9.1141e-01, 6.7823e-02, 1.6846e-01, 3.5157e-01, 4.9473e-01,
#          5.7262e-01, 2.2386e-01, 8.9329e-03, 7.1351e-01],
#         [4.9132e-02, 2.8509e-01, 2.1845e-01, 4.7392e-01, 6.2021e-01, 8.0039e-01,
#          1.5777e-01, 6.4612e-01, 8.5171e-01, 9.9896e-01, 1.8967e-01, 6.1110e-01,
#          7.5712e-01, 7.0576e-01, 5.6473e-01, 1.8217e-01, 5.5628e-02, 1.0059e-01,
#          1.2596e-02, 2.4363e-01, 6.6092e-01, 3.8112e-01, 6.8990e-01, 1.6653e-01,
#          4.8173e-01, 2.0328e-01, 1.6988e-01, 9.1795e-01],
#         [3.4104e-01, 3.6334e-02, 7.0847e-01, 3.9592e-01, 2.3955e-01, 7.8833e-01,
#          6.5205e-01, 9.9838e-01, 2.0205e-01, 3.7085e-01, 2.8657e-01, 3.0645e-01,
#          5.8712e-01, 9.9553e-01, 8.1203e-01, 6.4734e-01, 9.9866e-01, 6.5460e-01,
#          3.1906e-02, 5.1723e-01, 1.8913e-01, 5.6413e-01, 1.1261e-01, 6.2637e-01,
#          9.1118e-01, 6.4704e-01, 3.9273e-01, 9.3810e-01],
#         [6.3318e-01, 9.1022e-01, 6.5810e-01, 9.4980e-01, 5.6977e-01, 7.7204e-01,
#          7.7002e-01, 2.4176e-01, 5.1897e-01, 8.7688e-01, 5.9349e-01, 3.8088e-01,
#          9.5095e-01, 6.9644e-01, 9.2872e-01, 8.8310e-01, 7.0252e-01, 5.7424e-01,
#          7.2837e-01, 6.5879e-01, 4.4028e-01, 8.0814e-01, 5.0914e-01, 2.3385e-01,
#          6.7421e-01, 4.1112e-01, 5.7637e-01, 6.7536e-01],
#         [4.3157e-01, 9.4891e-01, 6.3741e-01, 9.8151e-01, 8.5611e-01, 6.1323e-02,
#          8.5482e-01, 8.7698e-01, 4.0525e-01, 4.5672e-01, 4.7708e-02, 9.1708e-01,
#          7.8573e-01, 2.3361e-01, 5.9631e-01, 9.4742e-01, 1.6696e-01, 3.0170e-01,
#          1.8042e-01, 7.2081e-01, 9.9939e-01, 6.9509e-01, 7.9881e-02, 1.3787e-01,
#          8.3839e-01, 7.8153e-01, 8.2528e-01, 2.1712e-01],
#         [2.2479e-01, 8.2137e-01, 3.0064e-01, 9.2336e-01, 3.1951e-01, 8.7922e-01,
#          3.7037e-01, 9.4598e-01, 9.8605e-01, 2.1895e-01, 4.0199e-01, 7.5337e-01,
#          3.4830e-01, 7.1373e-01, 4.6123e-01, 3.8002e-01, 3.5367e-01, 4.4429e-01,
#          6.9498e-01, 4.8468e-01, 4.8881e-02, 9.3823e-01, 1.3065e-01, 5.1646e-01,
#          4.3795e-01, 6.6607e-01, 9.0300e-01, 3.3737e-01],
#         [8.4771e-01, 5.3178e-01, 8.7303e-01, 1.1585e-01, 6.6808e-01, 6.6632e-01,
#          6.6184e-02, 8.8116e-01, 2.5863e-01, 6.3358e-01, 1.9776e-01, 6.1750e-01,
#          1.5407e-01, 2.5778e-01, 9.8772e-01, 9.4499e-01, 3.8447e-01, 4.6194e-01,
#          5.7038e-01, 8.7111e-01, 4.3402e-01, 7.5209e-01, 3.4894e-01, 1.5233e-01,
#          1.8863e-01, 9.7401e-01, 2.3445e-01, 6.3023e-01],
#         [6.2456e-01, 4.9065e-01, 8.6122e-01, 8.1213e-01, 7.1619e-02, 3.5964e-01,
#          5.5491e-01, 9.6320e-01, 1.5198e-01, 2.3362e-01, 6.4562e-02, 8.2909e-01,
#          1.7598e-02, 8.9253e-01, 3.0547e-01, 1.9090e-01, 2.2071e-01, 7.4986e-01,
#          9.5261e-01, 5.4352e-01, 8.8416e-01, 9.3234e-01, 8.6623e-01, 3.6681e-01,
#          6.2848e-01, 7.6614e-01, 8.0872e-01, 3.4760e-01],
#         [6.7625e-01, 2.2304e-01, 6.6370e-01, 8.9444e-01, 6.2873e-01, 3.7807e-01,
#          9.6844e-01, 3.4304e-01, 8.3628e-01, 7.8781e-01, 9.2222e-02, 6.1540e-01,
#          3.0845e-01, 2.9956e-01, 9.7723e-01, 1.6785e-01, 4.4519e-01, 9.2218e-01,
#          2.7555e-01, 9.8155e-01, 4.7327e-01, 2.3614e-01, 3.8542e-01, 2.2379e-01,
#          4.2227e-02, 3.8674e-01, 7.8438e-01, 6.3424e-01],
#         [6.6922e-02, 3.6817e-01, 5.8958e-01, 1.4594e-03, 8.4677e-01, 9.9956e-01,
#          3.2012e-02, 4.5751e-01, 6.0611e-01, 8.9653e-01, 4.8717e-01, 1.4005e-01,
#          6.5026e-01, 7.7588e-01, 1.4139e-01, 4.2385e-01, 6.3474e-01, 7.5897e-02,
#          1.9377e-01, 9.8011e-01, 1.9268e-01, 4.7371e-01, 6.1695e-01, 6.1061e-01,
#          3.8091e-01, 4.2499e-02, 8.1888e-01, 2.2332e-02],
#         [9.7437e-01, 3.9681e-02, 2.1597e-01, 9.7033e-01, 4.6112e-01, 6.0219e-01,
#          2.4277e-01, 5.9692e-01, 5.3943e-01, 2.4798e-01, 1.7973e-01, 5.7336e-01,
#          3.8995e-02, 4.8107e-01, 7.3590e-01, 5.8984e-01, 8.5603e-01, 7.9305e-02,
#          5.1709e-01, 1.4650e-01, 1.9034e-01, 9.2424e-01, 7.8216e-01, 7.2324e-01,
#          6.7682e-01, 8.5196e-01, 7.9795e-01, 5.1566e-01],
#         [1.8311e-01, 3.9301e-01, 9.0628e-01, 2.1209e-01, 2.6861e-01, 2.3147e-01,
#          7.5962e-01, 7.0322e-01, 3.3702e-01, 3.3489e-01, 3.4925e-01, 1.5140e-01,
#          7.4541e-01, 7.8459e-01, 4.8094e-01, 8.2964e-01, 6.1255e-01, 2.5952e-01,
#          9.9131e-01, 8.2160e-01, 8.5665e-01, 4.9758e-01, 6.8714e-01, 6.2106e-01,
#          3.7505e-02, 7.1450e-01, 8.7683e-01, 8.4006e-01],
#         [4.5706e-01, 6.4551e-01, 3.0058e-01, 5.5877e-01, 1.9485e-01, 1.8402e-01,
#          2.1081e-01, 8.9346e-01, 6.6740e-01, 6.0916e-01, 3.7499e-01, 8.6175e-01,
#          1.7772e-01, 1.1197e-01, 5.7375e-01, 2.5932e-01, 5.5936e-01, 1.9115e-02,
#          6.9665e-01, 4.9924e-01, 9.0975e-01, 3.6710e-01, 8.5240e-01, 5.0707e-01,
#          9.0531e-01, 3.6638e-01, 9.2014e-01, 4.8318e-01],
#         [2.5953e-02, 2.4494e-01, 8.0237e-01, 3.5325e-01, 2.4682e-01, 3.1904e-02,
#          8.2091e-01, 2.9672e-01, 5.9147e-01, 5.5549e-01, 1.3381e-01, 6.2152e-01,
#          2.0699e-01, 5.6416e-01, 6.8718e-01, 8.2283e-02, 6.9298e-01, 1.3532e-01,
#          9.8962e-01, 9.3589e-01, 4.9706e-01, 6.2681e-01, 8.6699e-01, 1.5275e-01,
#          5.2228e-01, 4.9090e-01, 4.1778e-01, 7.0914e-01],
#         [7.4330e-01, 8.4897e-01, 8.5313e-01, 6.6975e-01, 3.1198e-01, 5.2845e-01,
#          3.4925e-01, 5.2295e-01, 7.5818e-01, 8.8207e-01, 2.2231e-01, 2.3881e-01,
#          4.0925e-01, 5.5242e-01, 8.2009e-01, 9.8225e-01, 8.8382e-01, 7.8778e-01,
#          8.8468e-01, 5.1865e-01, 6.3044e-01, 8.6684e-02, 2.6920e-01, 8.2890e-01,
#          3.0308e-01, 8.8819e-01, 7.3657e-01, 2.1936e-01],
#         [9.3639e-02, 4.7297e-02, 6.6277e-01, 2.5557e-01, 3.2557e-01, 2.1524e-01,
#          5.5479e-01, 7.2507e-01, 9.2624e-01, 2.7296e-01, 2.1873e-01, 3.4739e-01,
#          5.8511e-01, 2.1033e-01, 8.6318e-01, 8.8195e-01, 9.3638e-01, 1.5371e-01,
#          5.6657e-01, 9.4531e-01, 4.2707e-01, 4.3634e-01, 7.7846e-01, 5.6760e-01,
#          3.1190e-01, 6.2735e-01, 3.4337e-01, 8.0680e-01],
#         [9.0669e-01, 2.6555e-01, 2.7780e-01, 5.9448e-01, 5.1662e-01, 9.4980e-01,
#          1.9656e-01, 3.3709e-01, 4.2261e-02, 5.6142e-01, 3.9168e-01, 8.5210e-01,
#          1.3465e-01, 6.2279e-01, 2.0077e-01, 6.0205e-01, 8.8441e-02, 3.9551e-01,
#          8.3210e-01, 9.4755e-01, 4.7121e-01, 3.9072e-01, 7.9383e-01, 7.3315e-01,
#          3.5441e-01, 2.6482e-01, 9.0159e-01, 5.6354e-01],
#         [8.8034e-01, 5.5867e-01, 1.2244e-01, 2.4289e-01, 1.4668e-01, 3.3886e-02,
#          7.2063e-01, 5.9302e-01, 4.3140e-01, 2.7266e-02, 7.3940e-01, 9.4945e-01,
#          7.1632e-01, 7.3635e-01, 2.5502e-01, 2.7653e-01, 8.9262e-01, 6.1646e-01,
#          3.7071e-01, 2.1993e-01, 1.5502e-01, 7.4215e-01, 3.1098e-01, 6.0051e-01,
#          2.0100e-01, 7.5816e-01, 5.5983e-01, 6.3490e-02],
#         [4.8208e-01, 7.1341e-01, 7.3485e-01, 2.9951e-01, 8.7792e-01, 6.1079e-01,
#          6.4665e-01, 3.8126e-01, 2.6887e-01, 7.1467e-01, 7.7075e-01, 6.9331e-01,
#          2.1388e-01, 5.6908e-01, 7.6847e-02, 4.0070e-02, 9.5845e-01, 2.8103e-01,
#          2.1822e-01, 4.8346e-01, 7.4681e-01, 1.0280e-01, 7.6701e-01, 6.5107e-01,
#          5.1265e-02, 5.2933e-01, 1.5206e-01, 9.4808e-01],
#         [9.7936e-01, 9.6779e-02, 6.1308e-01, 1.5473e-02, 8.6332e-01, 6.6143e-03,
#          4.7140e-01, 6.4155e-01, 3.2365e-01, 1.2944e-02, 6.2831e-01, 1.0758e-01,
#          2.7916e-01, 7.3870e-02, 1.4502e-01, 7.5281e-01, 9.4794e-02, 8.2207e-01,
#          4.6009e-01, 8.6137e-01, 4.2468e-03, 6.8629e-01, 4.7187e-01, 4.7569e-01,
#          9.2978e-01, 4.0493e-01, 8.1872e-01, 4.0167e-01],
#         [5.2075e-01, 5.1696e-01, 2.1328e-01, 7.1362e-01, 6.5656e-02, 1.4395e-01,
#          6.5393e-01, 1.7721e-01, 7.8086e-01, 1.7709e-01, 1.3694e-01, 4.6340e-01,
#          6.8287e-01, 8.7269e-01, 4.8049e-01, 5.8643e-01, 9.6136e-01, 5.2064e-01,
#          3.0534e-01, 1.1823e-01, 9.6269e-01, 7.7620e-01, 7.4009e-01, 8.1544e-02,
#          5.3998e-02, 6.0831e-01, 6.5734e-02, 3.8894e-01],
#         [8.1897e-02, 5.8692e-01, 6.7505e-01, 8.7672e-01, 7.7607e-01, 7.5359e-01,
#          8.4246e-01, 1.2183e-01, 9.5647e-01, 1.7721e-01, 9.2074e-01, 8.4914e-01,
#          9.2571e-01, 4.2618e-01, 7.2553e-01, 6.8615e-01, 1.6065e-01, 4.0821e-01,
#          7.0732e-01, 3.9457e-01, 3.9672e-02, 9.0431e-01, 9.7571e-01, 6.9151e-01,
#          5.4019e-01, 8.5233e-01, 6.4439e-01, 2.3038e-01],
#         [6.2982e-01, 1.5684e-01, 1.0454e-01, 4.7503e-01, 1.9091e-01, 4.9343e-01,
#          4.5014e-01, 3.6591e-01, 5.6825e-01, 6.6528e-01, 5.1990e-01, 8.2382e-01,
#          8.7961e-01, 6.6665e-01, 6.3966e-01, 1.0601e-01, 8.1789e-01, 5.5720e-01,
#          9.2902e-01, 6.1239e-01, 3.8029e-01, 8.8065e-02, 8.2061e-01, 6.9897e-01,
#          3.2399e-02, 4.2197e-01, 7.2411e-01, 7.1773e-01]])

# %% [markdown]
# To display an image from a PyTorch tensor, you can use the `matplotlib` library. Here's an example of how you would display the image. We use the `imshow` function from `matplotlib.pyplot` to display the image. The `cmap='gray'` argument ensures that the image is displayed in grayscale.

# %%
plt.imshow(second_image, cmap='gray')
plt.show()

# %% [markdown]
# Since we used `torch.rand` to generate these four images randomly, we get noise as expected.
# If you are familiar with matrices, then you will be at home with PyTorch tensors, since they offer all the same things you can do with a matrix. For instance, take the 2x2 matrix A. Let’s calculate the 1st, 2nd, 3rd, and 4th powers of this matrix, using matrix multiplication.

# %%
A = torch.tensor([[1, 1], [1, 0]], dtype=torch.float32)
print("A^1:\n", torch.matrix_power(A, 1))
print("A^2:\n", torch.matrix_power(A, 2))
print("A^3:\n", torch.matrix_power(A, 3))
print("A^4:\n", torch.matrix_power(A, 4))
# Out:
# A^1:
#  tensor([[1., 1.],
#         [1., 0.]])
# A^2:
#  tensor([[2., 1.],
#         [1., 1.]])
# A^3:
#  tensor([[3., 2.],
#         [2., 1.]])
# A^4:
#  tensor([[5., 3.],
#         [3., 2.]])

# %% [markdown]
# ## Neural Nets in PyTorch
#
# Moving on, PyTorch provides robust tools for the creation and manipulation of neural networks. Think of neural networks as intricate systems of interconnected nodes. Each node or neuron processes input and transmits the result to subsequent nodes. The simplest form of a neural network is a Multi-Layer Perceptron (MLP). In an MLP, there is an input layer, an output layer, and any number of hidden layers in the middle. Let’s make a Multi-Layer Perceptron with one hidden layer using PyTorch.

# %%
import torch.nn as nn

class MLP(nn.Module):
    def __init__(self, input_size):
        super(MLP, self).__init__()
        self.hidden_layer = nn.Linear(input_size, 64)
        self.activation = nn.ReLU()
        self.output_layer = nn.Linear(64, 2)

    def forward(self, x):
        x = self.hidden_layer(x)
        x = self.activation(x)
        x = self.output_layer(x)
        return x

# %% [markdown]
# We can now instantiate the multi-layer perceptron with an input size of 10 and print the model to review the sizes of our layers.

# %%
model = MLP(input_size=10)
print(model)
# Out:
# MLP(
#   (hidden_layer): Linear(in_features=10, out_features=64, bias=True)
#   (activation): ReLU()
#   (output_layer): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# We can test out the `forward` method of the model by passing in a vector of length 10. As expected, we receive a vector of length 2.

# %%
input_vector = torch.randn(10)
output = model(input_vector)
print(output)
# Out:
# tensor([-0.1153,  0.1572], grad_fn=<ViewBackward0>)

# %% [markdown]
# ## Loss Functions
#
# Let’s discuss loss functions in PyTorch now. Loss functions play a pivotal role in guiding model optimization. These functions quantify the discrepancy between the predicted output and the actual target values. We’ll look at two very important building blocks: Cross-Entropy Loss and Mean Squared Error (MSE) Loss.
#
# We start with a cross-entropy loss function, which is suited for classification tasks.

# %%
cross_entropy_loss = nn.CrossEntropyLoss()
target = torch.tensor([1]) # 0 for cats, 1 for dogs. Label is for dog.

# Case 1: Prediction is more likely a dog
predicted1 = torch.tensor([[2.0, 5.0]])

# %%
loss1 = cross_entropy_loss(predicted1, target)
loss1.item()
# Out:
# 0.04858732968568802

# %%
print(f"Loss when prediction is more likely a dog: {loss1.item():.4f}")

# Case 2: Prediction is more likely a cat
predicted2 = torch.tensor([[1.5, 1.1]])
loss2 = cross_entropy_loss(predicted2, target)
print(f"Loss when prediction is more likely a cat: {loss2.item():.4f}")
# Out:
# Loss when prediction is more likely a dog: 0.0486
# Loss when prediction is more likely a cat: 0.9130

# %% [markdown]
# Mean Squared Error (MSE) Loss is commonly employed in regression problems. Consider a situation where we aim to predict house prices. Let's say for a specific house, our model predicts a price of $320,000, but the actual price is $300,000.

# %%
mse_loss = nn.MSELoss()
predicted_price = torch.tensor([320000.0])
actual_price = torch.tensor([300000.0])
loss = mse_loss(predicted_price, actual_price)
print(f"MSE Loss: {loss.item()}")
# Out:
# MSE Loss: 400000000.0

# %% [markdown]
# ## PyTorch Optimizers
#
# After we have a loss function, we need to train the model by minimizing its loss function. For this, we use a PyTorch optimizer. One popular optimizer is Stochastic Gradient Descent (SGD).

# %%
from torch.optim import SGD, Adam

# Assuming 'model' is our MLP defined earlier
optimizer_sgd = SGD(model.parameters(), lr=0.01, momentum=0.9)
print("SGD Optimizer instantiated.")

# Adam is another popular optimizer.
optimizer_adam = Adam(model.parameters(), lr=0.01)
print("Adam Optimizer instantiated.")
# Out:
# SGD Optimizer instantiated.
# Adam Optimizer instantiated.

# %% [markdown]
# ## Datasets and DataLoaders
#
# In the PyTorch framework, the handling of data is facilitated through the `Dataset` class and the `DataLoader` utility. The `Dataset` class serves as a blueprint for how data is accessed and transformed, while the `DataLoader` is a utility that wraps around a `Dataset` object to provide batched, shuffled, and parallelized loading of data.
#
# Let's design an example to define a dataset for returning pairs of numbers and their products.

# %%
from torch.utils.data import Dataset, DataLoader

class NumberProductDataset(Dataset):
    def __init__(self, data_range):
        self.data = [(i, i + 1, i * (i + 1)) for i in range(data_range)]

    def __getitem__(self, idx):
        return self.data[idx]

    def __len__(self):
        return len(self.data)

dataset = NumberProductDataset(data_range=11)
sample = dataset[3] # pick the 4th element (index 3)
print(f"Input: {sample[0]}, {sample[1]}, Output: {sample[2]}")
# Out:
# Input: 3, 4, Output: 12

# %% [markdown]
# Now let's turn to the example of the `DataLoader`. Our data loader will take our `NumberProductDataset` as an input. We will also specify a batch size of three and set shuffle to true.

# %%
dataloader = DataLoader(dataset, batch_size=3, shuffle=True)
for i, (input1, input2, output) in enumerate(dataloader):
    print(f"Batch {i+1}:")
    print(f"  Inputs 1: {input1}")
    print(f"  Inputs 2: {input2}")
    print(f"  Outputs: {output}")
# Out:
# Batch 1:
#   Inputs 1: tensor([10,  8,  0])
#   Inputs 2: tensor([11,  9,  1])
#   Outputs: tensor([110,  72,   0])
# Batch 2:
#   Inputs 1: tensor([2, 6, 1])
#   Inputs 2: tensor([3, 7, 2])
#   Outputs: tensor([ 6, 42,  2])
# Batch 3:
#   Inputs 1: tensor([4, 9, 3])
#   Inputs 2: tensor([ 5, 10,  4])
#   Outputs: tensor([20, 90, 12])
# Batch 4:
#   Inputs 1: tensor([5, 7])
#   Inputs 2: tensor([6, 8])
#   Outputs: tensor([30, 56])

# %% [markdown]
# ## Training Loop
#
# Ok. Now we’re at the final step. Let's bring together all the components of PyTorch and show a full-fledged training loop!
#
# For this example, we will create a simple dataset, consisting of pairs of numbers and their sums.

# %%
class NumberSumDataset(Dataset):
    def __init__(self, data_range):
        self.data = []
        for i in range(data_range):
            for j in range(data_range):
                self.data.append(([i, j], i + j))

    def __getitem__(self, idx):
        return torch.tensor(self.data[idx][0], dtype=torch.float32), torch.tensor(self.data[idx][1], dtype=torch.float32)

    def __len__(self):
        return len(self.data)

# Print the first five elements to verify
sum_dataset = NumberSumDataset(data_range=10)
for i in range(5):
    print(sum_dataset[i])
# Out:
# (tensor([0., 0.]), tensor(0.))
# (tensor([0., 1.]), tensor(1.))
# (tensor([0., 2.]), tensor(2.))
# (tensor([0., 3.]), tensor(3.))
# (tensor([0., 4.]), tensor(4.))

# %% [markdown]
# Next, we define a multi-layer perceptron with 128 nodes in its hidden layer and a single node in its output layer. For the activation function, we use a rectified linear unit.

# %%
class SumMLP(nn.Module):
    def __init__(self):
        super(SumMLP, self).__init__()
        self.hidden_layer = nn.Linear(2, 128)
        self.activation = nn.ReLU()
        self.output_layer = nn.Linear(128, 1)

    def forward(self, x):
        x = self.hidden_layer(x)
        x = self.activation(x)
        x = self.output_layer(x)
        return x

# %% [markdown]
# All of the components needed for the training loop are listed here.

# %%
sum_dataset = NumberSumDataset(data_range=10)
sum_dataloader = DataLoader(sum_dataset, batch_size=10, shuffle=True)
sum_model = SumMLP()
loss_function = nn.MSELoss()
optimizer = Adam(sum_model.parameters(), lr=0.01)

# %% [markdown]
# Here is the training loop!

# %%
num_epochs = 20
for epoch in range(num_epochs):
    epoch_loss = 0.0
    for inputs, targets in sum_dataloader:
        optimizer.zero_grad() # Gradients = 0
        predictions = sum_model(inputs) #Forward pass
        loss = loss_function(predictions.squeeze(), targets) # Compute loss
        loss.backward() # Backpropagation, Compute gradients for this batch (added to 0, so they're "fresh")
        optimizer.step() # Update parameters using only this batch's gradients
        epoch_loss += loss.item()
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/len(sum_dataloader):.4f}")
# Out:
# Epoch 1/20, Loss: 23.5775
# Epoch 2/20, Loss: 5.4806
# Epoch 3/20, Loss: 3.2277
# Epoch 4/20, Loss: 0.8485
# Epoch 5/20, Loss: 0.3303
# Epoch 6/20, Loss: 0.2093
# Epoch 7/20, Loss: 0.0855
# Epoch 8/20, Loss: 0.0347
# Epoch 9/20, Loss: 0.0170
# Epoch 10/20, Loss: 0.0105
# Epoch 11/20, Loss: 0.0060
# Epoch 12/20, Loss: 0.0043
# Epoch 13/20, Loss: 0.0026
# Epoch 14/20, Loss: 0.0023
# Epoch 15/20, Loss: 0.0018
# Epoch 16/20, Loss: 0.0018
# Epoch 17/20, Loss: 0.0016
# Epoch 18/20, Loss: 0.0016
# Epoch 19/20, Loss: 0.0011
# Epoch 20/20, Loss: 0.0010

# %% [markdown]
# Now it's time to try our model out! What about using the numbers 3 and 7?

# %%
test_input = torch.tensor([3.0, 7.0])
prediction = sum_model(test_input)
print(f"Prediction for 3 + 7: {prediction.item():.1f}")
# Out:
# Prediction for 3 + 7: 10.0

# %% [markdown]
# Now you understand the core building blocks of PyTorch, equipping you with essential tools for developing powerful machine learning models.
